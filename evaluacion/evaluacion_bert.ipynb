# %%
from sklearn import metrics

# Constants
H = "HATE"
O = "NO_HATE"

# valores Reales
y_true = [
    O, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    O, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, O, H, H, O, O, H, H,
    O, H, H, H, H, O, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, O, H, H, O, O, H, H, O
]
# valores Predichos
y_pred = [
    O, H, H, H, H, H, H, H, H, H,
    H, H, H, O, H, H, H, H, H, O,
    H, H, H, H, O, O, O, O, H, O,
    H, O, H, H, H, H, H, H, H, O,
    H, H, O, O, H, O, H, H, H, H,
    H, H, H, O, H, H, H, H, H, H,
    H, H, H, O, O, H, O, O, H, H,
    O, O, H, H, H, O, H, H, H, O,
    H, H, O, H, H, H, H, H, O, H,
    O, H, H, H, H, H, H, H, H, H,
    O, H, H, O, H, H, H, H, H, H,
    H, H, O, H, H, O, H, O, H, O
]

# Mostrar confusion matrix
matrix = metrics.confusion_matrix(y_true, y_pred)

# Mostrar precision and recall, junto con el resto de métricas
print(metrics.classification_report(y_true, y_pred, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#         HATE      0.978     0.798     0.879       109
#      NO_HATE      0.290     0.818     0.429        11
#
#     accuracy                          0.800       120
#    macro avg      0.634     0.808     0.654       120
# weighted avg      0.915     0.800     0.838       120

# %%
import matplotlib.pyplot as plt
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=matrix, display_labels=[H, O])
cm_display.plot()
plt.show()
