# %%
from sklearn import metrics

# Constants
H = "HATE"
O = "NO_HATE"

# valores Reales
y_true = [
    O, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    O, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, O, H, H, O, O, H, H,
    O, H, H, H, H, O, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, O, H, H, O, O, H, H, O
]
# valores Predichos
y_pred = [
    O, H, O, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, O, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    O, H, H, H, H, O, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, O, H, O, H, H, O, O, H, H,
    O, H, H, H, H, O, O, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, O, H, H, O, H, H, H, O
]

# Mostrar confusion matrix
matrix = metrics.confusion_matrix(y_true, y_pred)

# Mostrar precision and recall, junto con el resto de métricas
print(metrics.classification_report(y_true, y_pred, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#         HATE      0.990     0.954     0.972       109
#      NO_HATE      0.667     0.909     0.769        11
#
#     accuracy                          0.950       120
#    macro avg      0.829     0.932     0.871       120
# weighted avg      0.961     0.950     0.953       120

# %%
import matplotlib.pyplot as plt
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=matrix, display_labels=[H, O])
cm_display.plot()
plt.show()
