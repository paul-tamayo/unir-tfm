# %%
from sklearn import metrics

# Constants
H = "HATE"
O = "NO_HATE"

# valores Reales
y_true = [
    O, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    O, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, O, H, H, O, O, H, H,
    O, H, H, H, H, O, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, O, H, H, O, O, H, H, O
]
# valores Predichos
y_pred = [
    O, H, H, O, H, O, H, H, O, H,
    H, H, H, H, H, H, H, H, H, H,
    H, H, O, H, H, O, O, O, H, H,
    H, H, O, H, H, H, O, H, H, H,
    H, O, O, O, O, O, O, H, H, O,
    H, H, H, O, O, H, H, O, H, H,
    H, H, O, O, H, H, O, O, H, H,
    O, H, O, H, H, O, O, H, H, H,
    O, H, H, O, H, H, H, H, O, H,
    H, H, H, H, H, O, O, O, O, H,
    O, H, O, O, O, H, H, O, H, H,
    H, H, O, H, H, O, H, O, O, O
]

# Mostrar confusion matrix
matrix = metrics.confusion_matrix(y_true, y_pred)

# Mostrar precision and recall, junto con el resto de métricas
print(metrics.classification_report(y_true, y_pred, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#         HATE      0.973     0.670     0.793       109
#      NO_HATE      0.200     0.818     0.321        11
#
#     accuracy                          0.683       120
#    macro avg      0.587     0.744     0.557       120
# weighted avg      0.902     0.683     0.750       120

# %%
import matplotlib.pyplot as plt
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=matrix, display_labels=[H, O])
cm_display.plot()
plt.show()
